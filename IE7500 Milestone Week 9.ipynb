# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Load BioBERT Model and Tokenizer
bio_bert_model = "dmis-lab/biobert-base-cased-v1.1"
tokenizer = AutoTokenizer.from_pretrained(bio_bert_model)
model = AutoModel.from_pretrained(bio_bert_model)

def get_bert_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).numpy()  # Get embedding vector

# %%
import pandas as pd

# Load your dataset (update path as needed)
df = pd.read_excel("MilestoneW9Data.xlsx")

# Preprocess symptoms
df["Symptoms"] = df["Symptoms"].str.lower().str.replace(", ", ",")
df["Symptom_List"] = df["Symptoms"].apply(lambda x: x.split(","))
df["Symptom_String"] = df["Symptom_List"].apply(lambda x: " ".join(x))

# Generate BioBERT embeddings
df["Symptom_Embedding"] = df["Symptom_String"].apply(lambda x: get_bert_embedding(x).flatten())

# Save processed dataset
df.to_csv("BioBERT_Disease_Embeddings.csv", index=False)

# %%
import pandas as pd
import numpy as np
import torch
import re
from transformers import AutoTokenizer, AutoModel, AutoConfig
from sklearn.metrics.pairwise import cosine_similarity
import ast  # Securely evaluate stored embeddings

config = AutoConfig.from_pretrained("dmis-lab/biobert-base-cased-v1.1", timeout=1000)
tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-base-cased-v1.1", config=config)
model = AutoModel.from_pretrained("dmis-lab/biobert-base-cased-v1.1", config=config)

# Load the processed dataset with BioBERT embeddings
df = pd.read_csv("BioBERT_Disease_Embeddings.csv")



def clean_embedding(embedding_str):
    """
    Cleans and converts the stored embedding string into a proper NumPy array.
    - Replaces multiple spaces with a single space.
    - Ensures the format is valid before conversion.
    """
    cleaned_str = re.sub(r'\s+', ',', embedding_str.strip())  # Replace spaces with commas
    cleaned_str = cleaned_str.replace("[,", "[").replace(",]", "]")  # Fix edge cases
    return np.array(ast.literal_eval(cleaned_str))  # Convert string to NumPy array

# Apply the cleaning function
df["Symptom_Embedding"] = df["Symptom_Embedding"].apply(lambda x: clean_embedding(x))

# Load BioBERT Model and Tokenizer
bio_bert_model = "dmis-lab/biobert-base-cased-v1.1"
tokenizer = AutoTokenizer.from_pretrained(bio_bert_model)
model = AutoModel.from_pretrained(bio_bert_model)

def get_bert_embedding(text):
    """Generate BioBERT embeddings for user input symptoms."""
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).numpy()  # Get embedding vector

def predict_disease(user_symptoms):
    """
    Predicts the most probable disease(s) based on user symptoms.
    """
    # Generate BioBERT embedding for user input
    user_embedding = get_bert_embedding(user_symptoms).flatten().reshape(1, -1)

    # Compute cosine similarity with stored disease embeddings
    stored_embeddings = np.stack(df["Symptom_Embedding"].values)
    similarity_scores = cosine_similarity(user_embedding, stored_embeddings).flatten()

    # Get top 2 most similar diseases
    top_indices = similarity_scores.argsort()[-2:][::-1]
    predicted_diseases = df.iloc[top_indices][["Disease", "Note"]].reset_index(drop=True)

    return predicted_diseases

# Example: Predict disease for user symptoms
user_input = "fever, chills, muscle pain, headache"
predicted_result = predict_disease(user_input)

# Display Results
print("Predicted Diseases:")
print(predicted_result)
# Out:
# Predicted Diseases:
#         Disease                                               Note
# 0       Malaria  Caused by Plasmodium parasites transmitted thr...
# 1  Yellow Fever    Yellow fever is a mosquito-borne viral disease.

# %%
pip install jupyterlab-git
# Out:
# Collecting jupyterlab-git
#   Downloading jupyterlab_git-0.51.0-py3-none-any.whl.metadata (32 kB)
# Collecting jupyter-server<3,>=2.0.1 (from jupyterlab-git)
#   Downloading jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting nbdime~=4.0.1 (from jupyterlab-git)
#   Downloading nbdime-4.0.2-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: nbformat in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyterlab-git) (5.3.0)
# Requirement already satisfied: packaging in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyterlab-git) (24.1)
# Collecting pexpect (from jupyterlab-git)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: traitlets~=5.0 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyterlab-git) (5.1.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (3.5.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (3.1.4)
# Collecting jupyter-client>=7.4.4 (from jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (6.5.0)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (2.0.5)
# Collecting pyzmq>=24 (from jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading pyzmq-26.3.0-cp38-cp38-win_amd64.whl.metadata (6.2 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.13.3)
# Collecting tornado>=6.2.0 (from jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading tornado-6.4.2-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
# Collecting traitlets~=5.0 (from jupyterlab-git)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (1.8.0)
# Requirement already satisfied: colorama in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (0.4.6)
# Collecting gitpython!=2.1.4,!=2.1.5,!=2.1.6 (from nbdime~=4.0.1->jupyterlab-git)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting jupyter-server-mathjax>=0.2.2 (from nbdime~=4.0.1->jupyterlab-git)
#   Downloading jupyter_server_mathjax-0.2.6-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pygments in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.19.1)
# Requirement already satisfied: requests in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.32.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbformat->jupyterlab-git) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbformat->jupyterlab-git) (2.15.3)
# Collecting ptyprocess>=0.5 (from pexpect->jupyterlab-git)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.2.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (21.2.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jsonschema>=2.6->nbformat->jupyterlab-git) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jsonschema>=2.6->nbformat->jupyterlab-git) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jsonschema>=2.6->nbformat->jupyterlab-git) (5.7.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.8.2)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pywin32>=300 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab-git) (302)
# Collecting jsonschema>=2.6 (from nbformat->jupyterlab-git)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.0.2)
# Collecting referencing (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat->jupyterlab-git)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat->jupyterlab-git)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema>=2.6->nbformat->jupyterlab-git)
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat->jupyterlab-git)
#   Downloading rpds_py-0.20.1-cp38-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.11.1)
# Requirement already satisfied: bleach in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2.0.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2021.10.8)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from importlib-metadata>=4.8.3->jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.8.0)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading webcolors-24.8.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: nest-asyncio in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from nbclient>=0.5.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.5.5)
# Requirement already satisfied: six>=1.5 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.16.0)
# Requirement already satisfied: typing_extensions in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from python-json-logger>=2.0.4->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.12.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\arish\appdata\local\programs\python\python38\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.21)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading jupyterlab_git-0.51.0-py3-none-any.whl (367 kB)
# Downloading jupyter_server-2.14.2-py3-none-any.whl (383 kB)
# Downloading nbdime-4.0.2-py3-none-any.whl (5.9 MB)
#    ---------------------------------------- 5.9/5.9 MB 1.7 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading jupyter_server_mathjax-0.2.6-py3-none-any.whl (3.1 MB)
#    ---------------------------------------- 3.1/3.1 MB 1.6 MB/s eta 0:00:00
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pyzmq-26.3.0-cp38-cp38-win_amd64.whl (648 kB)
#    ---------------------------------------- 648.1/648.1 kB 1.1 MB/s eta 0:00:00
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading tornado-6.4.2-cp38-abi3-win_amd64.whl (438 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rpds_py-0.20.1-cp38-none-win_amd64.whl (218 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading webcolors-24.8.0-py3-none-any.whl (15 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: ptyprocess, webcolors, uri-template, types-python-dateutil, traitlets, tornado, smmap, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyzmq, python-json-logger, platformdirs, pkgutil-resolve-name, pexpect, overrides, jsonpointer, fqdn, attrs, referencing, jupyter-core, gitdb, arrow, jupyter-server-terminals, jupyter-client, jsonschema-specifications, isoduration, gitpython, jsonschema, jupyter-events, jupyter-server, jupyter-server-mathjax, nbdime, jupyterlab-git
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: send2trash
#     Found existing installation: Send2Trash 1.8.0
#     Uninstalling Send2Trash-1.8.0:
#       Successfully uninstalled Send2Trash-1.8.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 22.3.0
#     Uninstalling pyzmq-22.3.0:
#       Successfully uninstalled pyzmq-22.3.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
#       Successfully uninstalled attrs-21.2.0
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.10.0
#     Uninstalling jupyter-core-4.10.0:
#       Successfully uninstalled jupyter-core-4.10.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 7.2.2
#     Uninstalling jupyter-client-7.2.2:
#       Successfully uninstalled jupyter-client-7.2.2
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.4.0
#     Uninstalling jsonschema-4.4.0:
#       Successfully uninstalled jsonschema-4.4.0
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.16.0
#     Uninstalling jupyter-server-1.16.0:
#       Successfully uninstalled jupyter-server-1.16.0
# Successfully installed arrow-1.3.0 attrs-25.3.0 fqdn-1.5.1 gitdb-4.0.12 gitpython-3.1.44 isoduration-20.11.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 jupyter-client-8.6.3 jupyter-core-5.7.2 jupyter-events-0.10.0 jupyter-server-2.14.2 jupyter-server-mathjax-0.2.6 jupyter-server-terminals-0.5.3 jupyterlab-git-0.51.0 nbdime-4.0.2 overrides-7.7.0 pexpect-4.9.0 pkgutil-resolve-name-1.3.10 platformdirs-4.3.6 ptyprocess-0.7.0 python-json-logger-3.3.0 pyzmq-26.3.0 referencing-0.35.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.20.1 send2trash-1.8.3 smmap-5.0.2 tornado-6.4.2 traitlets-5.14.3 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 webcolors-24.8.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Arish\AppData\Local\Programs\Python\Python38\Lib\site-packages\~ornado'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Arish\AppData\Local\Programs\Python\Python38\Lib\site-packages\~yzmq.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Arish\AppData\Local\Programs\Python\Python38\Lib\site-packages\~mq'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab 3.3.4 requires jupyter-server~=1.4, but you have jupyter-server 2.14.2 which is incompatible.
# jupyterlab-server 2.13.0 requires jupyter-server<2,>=1.8, but you have jupyter-server 2.14.2 which is incompatible.
# notebook-shim 0.1.0 requires jupyter-server~=1.8, but you have jupyter-server 2.14.2 which is incompatible.

# %%
git add origin https://github.com/arishbukhari1/Intelligent-Medical-Chatbot.git
# Out:
#   Input In [3]
#     git add origin https://github.com/arishbukhari1/Intelligent-Medical-Chatbot.git
#         ^
# SyntaxError: invalid syntax
